# %% [markdown]
# <a href="https://colab.research.google.com/github/DinaKSari/244107020072_PEMBELAJARAN_MESIN/blob/main/TG1_244107020072_DINA_KUMALA_SARI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPREP
# !pip install Scypy
# !pip install wandb
# !pip install pyECG
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 52.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
# ...

# %% [markdown]
# # Penjelasan
# ## PyPREP
# pyprep adalah implementasi Python dari Preprocessing Pipeline (PREP) untuk data EEG, yang bekerja dengan MNE-Python<br> <br>
#
# ## Scypy
# SciPy adalah pustaka komputasi ilmiah yang menggunakan NumPy sebagai dasarnya. SciPy adalah singkatan dari Scientific Python. Ini menyediakan lebih banyak fungsi utilitas untuk optimasi, statistik, dan pemrosesan sinyal. Seperti NumPy, SciPy adalah perangkat lunak sumber terbuka sehingga kita dapat menggunakannya secara bebas. <br> <br>
#
# ## wandb
# Library python untuk memvisualisasikan, dan mengelola eksperimen pembelajaran mesin <br><br>
#
# ## pyECG
# pyECG adalah paket Python sumber terbuka yang mendukung pembacaan/penulisan format dataset EKG umum. <br><br>

# %% [markdown]
# # BAGIAN 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
# jawab: Contoh kasus yang terjadi di sekolah menengah Pikesville, Maryland, Amerika Serikat, ketika direktur atletik Dazhon Darien sengaja membuat rekaman suara menggunakan AI. Rekaman itu meniru suara kepala sekolah Eric Eiswert dan berisi ujaran rasis anti semit, yang kemudian disebarkan ke email guru hingga viral di medsos.<br>
# refrensi: https://www.liputan6.com/global/read/5586757/kasus-terbaru-penyalahgunaan-ai-suara-kepala-sekolah-di-as-berisi-ucapan-rasis
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
# jawab: contoh dampak penggunaan AI terhadap energi dan lingkungan, situs Character AI menggunakan pasokan air yang banyak untuk mendinginkan system karena GPU nya panas.<br>
# referensi: https://aimetrix.org/character-ai-environmental-impact/
